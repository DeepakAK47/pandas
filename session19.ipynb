# %% [markdown]
# ### groupby command

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('movies.csv')

# %%
data.head(5)
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %% [raw]
# -> groupby command is applicable only for categorical data

# %%
genre = data.groupby('Genre')

# %%
genre.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
genre.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genre.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
# find the top three movies based on the genre
data.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# find the genre with the highest IMDM rating
data.groupby('Genre')['IMDB_Rating'].sum().head(3)
# Out:
# Genre
# Action       1367.3
# Adventure     571.5
# Animation     650.3
# Name: IMDB_Rating, dtype: float64

# %%
# find the genre with the highest IMDM rating
data.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False)
# Out:
# Genre
# Western      8.350000
# Crime        8.016822
# Fantasy      8.000000
# Mystery      7.975000
# Film-Noir    7.966667
# Drama        7.957439
# Action       7.949419
# Biography    7.938636
# Adventure    7.937500
# Animation    7.930488
# Horror       7.909091
# Comedy       7.901290
# Family       7.800000
# Thriller     7.800000
# Name: IMDB_Rating, dtype: float64

# %%
# find the director with most popularity
data.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
# Find the highest rated movie of each genre (Wrong answer)
data.groupby('Genre')['IMDB_Rating'].sum().sort_values(ascending=False).head()
# Out:
# Genre
# Drama        2299.7
# Action       1367.3
# Comedy       1224.7
# Crime         857.8
# Biography     698.6
# Name: IMDB_Rating, dtype: float64

# %%
# Find the highest rated movie of each genre
data.groupby('Genre')['IMDB_Rating'].max()
# Out:
# Genre
# Action       9.0
# Adventure    8.6
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.2
# Drama        9.3
# Family       7.8
# Fantasy      8.1
# Film-Noir    8.1
# Horror       8.5
# Mystery      8.4
# Thriller     7.8
# Western      8.8
# Name: IMDB_Rating, dtype: float64

# %% [raw]
# -> .sum() : this function just count all the numerical values

# %% [raw]
# // IMP

# %%
# find the number of movies done by each actor 
data.groupby('Star1').count()['Series_Title'].sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %%
# find the total number of groups
len(data.groupby('Genre'))
# Out:
# 14

# %%
# find items in each group
data.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
# find the starting first data
data.groupby('Genre').size().head()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# dtype: int64

# %%
# find the starting last data
data.groupby('Genre').size().tail()
# Out:
# Genre
# Film-Noir     3
# Horror       11
# Mystery      12
# Thriller      1
# Western       4
# dtype: int64

# %%
# accessing data from particular index
data.groupby('Genre')

# %%
data.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %%
data.groupby('Director').value_counts()
# Out:
# Director             Series_Title                Released_Year  Runtime  Genre      IMDB_Rating  Star1               No_of_Votes  Gross        Metascore
# Aaron Sorkin         The Trial of the Chicago 7  2020           129      Drama      7.8          Eddie Redmayne      89896        853090410.0  77.0         1
# Abdellatif Kechiche  La vie d'Adèle              2013           180      Drama      7.7          Léa Seydoux         138741       2199675.0    89.0         1
# Abhishek Kapoor      Kai po che!                 2013           130      Drama      7.7          Amit Sadh           32628        1122527.0    40.0         1
# Adam McKay           The Big Short               2015           130      Biography  7.8          Christian Bale      362942       70259870.0   81.0         1
# Akira Kurosawa       Kagemusha                   1980           180      Drama      8.0          Tatsuya Nakadai     32195        66363801.0   84.0         1
# ...

# %% [raw]
# -> agg function means you can apply sum/mean/mode all these function multiple times over data

# %%
# apply aggregation function over multiple columns 
genre = data.groupby('Genre').max()

# %%
genre
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
genres = data.groupby('Genre')

# %% [raw]
# -> This function is used for applying multiple commands using single funciton

# %%
genres.agg(
    {
        'Released_Year': 'mean',
        'Runtime' : 'max',
        'IMDB_Rating' : 'max',
        'No_of_Votes' : 'max'
    }
)
# Out:
#            Released_Year  Runtime  IMDB_Rating  No_of_Votes
# Genre
# Action       1997.081395      321          9.0      2303232
# Adventure    1986.450704      228          8.6      1512360
# Animation    2002.219512      137          8.6       999790
# Biography    1998.386364      209          8.9      1213505
# Comedy       1986.554839      188          8.6       939631
# Crime        1989.420561      229          9.2      1826188
# Drama        1988.948097      242          9.3      2343110
# Family       1976.500000      115          7.8       372490
# Fantasy      1921.000000       94          8.1        88794
# Film-Noir    1944.333333      108          8.1       158731
# Horror       1977.818182      122          8.5       787806
# Mystery      1986.166667      138          8.4      1129894
# Thriller     1967.000000      108          7.8        27733
# Western      1968.750000      165          8.8       688390

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
print(data['Released_Year'].dtype)
print(data['Released_Year'].unique())

# %% [raw]
# -> .dtype  function

# %%
# find the data type of a particular feature
data['Released_Year'].dtype
# Out:
# dtype('O')

# %%
data['Released_Year'] = pd.to_numeric(data['Released_Year'], errors='coerce')

# %%
data['Released_Year'].dtype
# Out:
# dtype('float64')

# %%
 Series_Title   1000 non-null   object 
 1   Released_Year  1000 non-null   object 
 2   Runtime        1000 non-null   int64  
 3   Genre          1000 non-null   object 
 4   IMDB_Rating    1000 non-null   float64
 5   Director       1000 non-null   object 
 6   Star1          1000 non-null   object 
 7   No_of_Votes    1000 non-null   int64  
 8   Gross          1000 non-null   float64
 9   Metascore

# %%
data2 = pd.read_csv('movies.csv')

# %% [raw]
# -> Use only particular column from the datasets

# %%
data2 = data2[['Released_Year','Runtime','IMDB_Rating','No_of_Votes','Gross','Genre']]

# %%
data2.head()
# Out:
#   Released_Year  Runtime  IMDB_Rating  No_of_Votes        Gross   Genre
# 0          1994      142          9.3      2343110   28341469.0   Drama
# 1          1972      175          9.2      1620367  134966411.0   Crime
# 2          2008      152          9.0      2303232  534858444.0  Action
# 3          1974      202          9.0      1129952   57300000.0   Crime
# 4          1957       96          9.0       689845    4360000.0   Crime

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Released_Year  1000 non-null   object
#  1   Runtime        1000 non-null   int64
#  2   IMDB_Rating    1000 non-null   float64
#  3   No_of_Votes    1000 non-null   int64
#  4   Gross          1000 non-null   float64
#  5   Genre          1000 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 47.0+ KB

# %%
data2['Released_Year'] = pd.to_numeric(data2['Released_Year'], errors='coerce')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Released_Year  999 non-null    float64
#  1   Runtime        1000 non-null   int64
#  2   IMDB_Rating    1000 non-null   float64
#  3   No_of_Votes    1000 non-null   int64
#  4   Gross          1000 non-null   float64
#  5   Genre          1000 non-null   object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 47.0+ KB

# %%
genres2 = data2.groupby('Genre')

# %%
# find the min,max,median of the Genre feature for its all categories
genres2.agg(['min','max','median'])
# Out:
#           Released_Year                 Runtime             IMDB_Rating       \
#                     min     max  median     min  max median         min  max
# Genre
# Action           1924.0  2019.0  2004.0      45  321  127.5         7.6  9.0
# Adventure        1925.0  2019.0  1990.0      88  228  127.0         7.6  8.6
# Animation        1940.0  2020.0  2004.0      71  137   99.5         7.6  8.6
# Biography        1928.0  2020.0  2004.0      93  209  129.0         7.6  8.9
# Comedy           1921.0  2020.0  1993.0      68  188  106.0         7.6  8.6
# Crime            1931.0  2019.0  1996.0      80  229  122.0         7.6  9.2
# Drama            1925.0  2020.0  1997.0      64  242  121.0         7.6  9.3
# Family           1971.0  1982.0  1976.5     100  115  107.5         7.8  7.8
# Fantasy          1920.0  1922.0  1921.0      76   94   85.0         7.9  8.1
# Film-Noir        1941.0  1949.0  1943.0     100  108  104.0         7.8  8.1
# ...

# %%
df = pd.DataFrame(columns=data.columns)  # creating an empty DataFrame
for group,date in genres:
    df = pd.concat([df, date[date['IMDB_Rating'] == date['IMDB_Rating'].max()]])
# Out:
# C:\Users\dspri\AppData\Local\Temp\ipykernel_11824\897752202.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, date[date['IMDB_Rating'] == date['IMDB_Rating'].max()]])

# %%
df
# Out:
#                             Series_Title  Released_Year Runtime      Genre  \
# 2                        The Dark Knight         2008.0     152     Action
# 21                          Interstellar         2014.0     169  Adventure
# 23         Sen to Chihiro no kamikakushi         2001.0     125  Animation
# 7                       Schindler's List         1993.0     195  Biography
# 19                          Gisaengchung         2019.0     132     Comedy
# 26                       La vita è bella         1997.0     116     Comedy
# 1                          The Godfather         1972.0     175      Crime
# 0               The Shawshank Redemption         1994.0     142      Drama
# 688           E.T. the Extra-Terrestrial         1982.0     115     Family
# 698  Willy Wonka & the Chocolate Factory         1971.0     100     Family
# 321         Das Cabinet des Dr. Caligari         1920.0      76    Fantasy
# ...

# %% [raw]
# -> split (apply) combine technique

# %%
# it goes in every column and find the minimum value for each category
genres.apply(min)
# Out:
# C:\Users\dspri\AppData\Local\Temp\ipykernel_11824\1443917609.py:1: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   genres.apply(min)
# C:\Users\dspri\AppData\Local\Temp\ipykernel_11824\1443917609.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(min)
#                               Series_Title  Released_Year  Runtime      Genre  \
# Genre
# Action                                 300         1924.0       45     Action
# ...

# %%
# find the number of movies start with A in each genres of group
df = pd.DataFrame(columns=data.columns)  # creating an empty DataFrame
for group,date in genres:
    df = pd.concat([df, date[date['Series_Title'].str[0] == 'A']])
# Out:
# C:\Users\dspri\AppData\Local\Temp\ipykernel_11824\951259526.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, date[date['Series_Title'].str[0] == 'A']])

# %%
df
# Out:
#                Series_Title  Released_Year Runtime   Genre  IMDB_Rating  \
# 59        Avengers: Endgame         2019.0     181  Action          8.4
# 60   Avengers: Infinity War         2018.0     149  Action          8.4
# 106                  Aliens         1986.0     137  Action          8.3
# 166         Andaz Apna Apna         1994.0     160  Action          8.2
# 224             A Wednesday         2008.0     104  Action          8.1
# ..                      ...            ...     ...     ...          ...
# 804           Abre los ojos         1997.0     119   Drama          7.7
# 813       A Little Princess         1995.0      97   Drama          7.7
# 824          A Few Good Men         1992.0     138   Drama          7.7
# 903          A Star Is Born         2018.0     136   Drama          7.6
# 75                    Alien         1979.0     117  Horror          8.4
#
#                Director             Star1 No_of_Votes        Gross  Metascore
# ...

# %%
# find the ranking of each movie based
