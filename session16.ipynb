# %%
import pandas as pd

# %%
country = ['India','Bangla','Pak','Nepal','India']
pd.Series(country)
# Out:
# 0     India
# 1    Bangla
# 2       Pak
# 3     Nepal
# 4     India
# dtype: object

# %%
subject = ['H','E','M','S']
marks = [12,13,14,15]
pd.Series(marks,index=subject)
# Out:
# H    12
# E    13
# M    14
# S    15
# dtype: int64
